# %% [markdown]
# # Summarization of transcripts with Langchain
#
# In this example, we intend to create a summarizer for long transcripts. The main goal is to break the original transcript into different chunks based on context - i.e. using an unsupervised approach to identify the different topics throughout the transcript (somehow similarly to Topic Modelling) - and summarize each of these chunks. in the end, the different summaries are returned to the user.

# %% [markdown]
# ## Step 0: Configuring the environment
#
# This step install the necessary libraries for connecting with Galileo and the models. When GenAI workspaces are available, most of the libraries will come pre-installed

# %%
# !pip install langchain-openai
# !pip install langchain-community
# !pip install langchain-huggingface
# !pip install langchain
# !pip install promptquality #Galileo
# !pip install chromadb
# !pip install sentence-transformers
# !pip install openai
# !pip install webvtt-py
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.1.23-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-core<0.3.0,>=0.2.35 (from langchain-openai)
#   Downloading langchain_core-0.2.37-py3-none-any.whl.metadata (6.2 kB)
# Collecting openai<2.0.0,>=1.40.0 (from langchain-openai)
#   Downloading openai-1.43.0-py3-none-any.whl.metadata (22 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (1.33)
# Collecting langsmith<0.2.0,>=0.1.75 (from langchain-core<0.3.0,>=0.2.35->langchain-openai)
#   Downloading langsmith-0.1.108-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (2.8.2)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain-core<0.3.0,>=0.2.35->langchain-openai)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.27.0)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.40.0->langchain-openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: sniffio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.66.3)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.2.2)
# Requirement already satisfied: certifi in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.35->langchain-openai) (3.0.0)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.35->langchain-openai)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.35->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.35->langchain-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.2)
# Downloading langchain_openai-0.1.23-py3-none-any.whl (51 kB)
# Downloading langchain_core-0.2.37-py3-none-any.whl (396 kB)
# Downloading openai-1.43.0-py3-none-any.whl (365 kB)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 504.1 kB/s eta 0:00:00a 0:00:01
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
# Downloading langsmith-0.1.108-py3-none-any.whl (150 kB)
# Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 kB 487.6 kB/s eta 0:00:00a 0:00:01
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
# Installing collected packages: tenacity, regex, orjson, jiter, tiktoken, openai, langsmith, langchain-core, langchain-openai
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed jiter-0.5.0 langchain-core-0.2.37 langchain-openai-0.1.23 langsmith-0.1.108 openai-1.43.0 orjson-3.10.7 regex-2024.7.24 tenacity-8.5.0 tiktoken-0.7.0
# Collecting langchain-community
#   Downloading langchain_community-0.2.15-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-community) (2.0.32)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain<0.3.0,>=0.2.15 (from langchain-community)
#   Downloading langchain-0.2.15-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.37 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-community) (0.2.37)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-community) (0.1.108)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-community) (1.24.3)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-community) (8.5.0)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (39 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.15->langchain-community)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain<0.3.0,>=0.2.15->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.37->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.37->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.37->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: anyio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.37->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.15->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.15->langchain-community) (2.20.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.2.2)
# Downloading langchain_community-0.2.15-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 496.6 kB/s eta 0:00:00a 0:00:01
# Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 209.7 kB/s eta 0:00:00a 0:00:01
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain-0.2.15-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 465.4 kB/s eta 0:00:00a 0:00:01
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
# Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (467 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, multidict, marshmallow, frozenlist, async-timeout, aiohappyeyeballs, yarl, typing-inspect, aiosignal, dataclasses-json, aiohttp, langchain-text-splitters, langchain, langchain-community
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 async-timeout-4.0.3 dataclasses-json-0.6.7 frozenlist-1.4.1 langchain-0.2.15 langchain-community-0.2.15 langchain-text-splitters-0.2.2 marshmallow-3.22.0 multidict-6.0.5 mypy-extensions-1.0.0 typing-inspect-0.9.0 yarl-1.9.7
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.0.3-py3-none-any.whl.metadata (1.2 kB)
# Collecting huggingface-hub>=0.23.0 (from langchain-huggingface)
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-huggingface) (0.2.37)
# Collecting sentence-transformers>=2.6.0 (from langchain-huggingface)
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting tokenizers>=0.19.1 (from langchain-huggingface)
#   Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting transformers>=4.39.0 (from langchain-huggingface)
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.66.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (0.1.108)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (8.5.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.2.1+cu118)
# Requirement already satisfied: numpy in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.24.3)
# Requirement already satisfied: scikit-learn in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.5.0)
# Requirement already satisfied: scipy in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.12.0)
# Requirement already satisfied: Pillow in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (10.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from transformers>=4.39.0->langchain-huggingface) (2024.7.24)
# Collecting safetensors>=0.4.1 (from transformers>=4.39.0->langchain-huggingface)
#   Downloading safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tokenizers>=0.19.1 (from langchain-huggingface)
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain-huggingface) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2024.7.4)
# Requirement already satisfied: sympy in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==8.7.0.84 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (8.7.0.84)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.19.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.8.86)
# Requirement already satisfied: triton==2.2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.2.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (3.5.0)
# Requirement already satisfied: anyio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (1.2.2)
# Downloading langchain_huggingface-0.0.3-py3-none-any.whl (17 kB)
# Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 434.5 kB/s eta 0:00:0000:0100:01
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 404.5 kB/s eta 0:00:00a 0:00:01
# Downloading safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers, sentence-transformers, langchain-huggingface
# Successfully installed huggingface-hub-0.24.6 langchain-huggingface-0.0.3 safetensors-0.4.4 sentence-transformers-3.0.1 tokenizers-0.19.1 transformers-4.44.2
# Requirement already satisfied: langchain in /opt/conda/envs/summarization/lib/python3.10/site-packages (0.2.15)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.35 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (0.2.37)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (0.1.108)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.35->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Collecting promptquality
#   Downloading promptquality-0.58.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting galileo-core<3.0.0,>=2.11.0 (from promptquality)
#   Downloading galileo_core-2.11.1-py3-none-any.whl.metadata (1.0 kB)
# Collecting importlib-metadata<9.0,>=8.0.0 (from promptquality)
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting numpy>=1.25.0 (from promptquality)
#   Downloading numpy-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from promptquality) (2.8.2)
# Collecting pydantic-settings<3.0.0,>=2.1.0 (from promptquality)
#   Downloading pydantic_settings-2.4.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyjwt<3.0.0,>=2.8.0 (from promptquality)
#   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from promptquality) (2.32.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from promptquality) (4.66.3)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from galileo-core<3.0.0,>=2.11.0->promptquality) (0.27.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from galileo-core<3.0.0,>=2.11.0->promptquality) (4.12.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from importlib-metadata<9.0,>=8.0.0->promptquality) (3.20.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->promptquality) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->promptquality) (2.20.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.1.0->promptquality)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->promptquality) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->promptquality) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->promptquality) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->promptquality) (2024.7.4)
# Requirement already satisfied: anyio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->galileo-core<3.0.0,>=2.11.0->promptquality) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->galileo-core<3.0.0,>=2.11.0->promptquality) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->galileo-core<3.0.0,>=2.11.0->promptquality) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->galileo-core<3.0.0,>=2.11.0->promptquality) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from anyio->httpx<0.28.0,>=0.27.0->galileo-core<3.0.0,>=2.11.0->promptquality) (1.2.2)
# Downloading promptquality-0.58.1-py3-none-any.whl (51 kB)
# Downloading galileo_core-2.11.1-py3-none-any.whl (42 kB)
# Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Downloading numpy-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 220.3 kB/s eta 0:00:0000:0100:03
# Downloading pydantic_settings-2.4.0-py3-none-any.whl (23 kB)
# Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, pyjwt, numpy, importlib-metadata, pydantic-settings, galileo-core, promptquality
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 7.2.1
#     Uninstalling importlib_metadata-7.2.1:
#       Successfully uninstalled importlib_metadata-7.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.2.15 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.1.0 which is incompatible.
# langchain-community 0.2.15 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.1.0 which is incompatible.
# matplotlib 3.8.2 requires numpy<2,>=1.21, but you have numpy 2.1.0 which is incompatible.
# mlflow 2.15.0 requires numpy<2, but you have numpy 2.1.0 which is incompatible.
# mlflow-skinny 2.15.0 requires importlib-metadata!=4.7.0,<8,>=3.7.0, but you have importlib-metadata 8.4.0 which is incompatible.
# numba 0.59.0 requires numpy<1.27,>=1.22, but you have numpy 2.1.0 which is incompatible.
# opentelemetry-api 1.26.0 requires importlib-metadata<=8.0.0,>=6.0, but you have importlib-metadata 8.4.0 which is incompatible.
# pandas 2.2.0 requires numpy<2,>=1.22.4; python_version < "3.11", but you have numpy 2.1.0 which is incompatible.
# pyarrow 15.0.2 requires numpy<2,>=1.16.6, but you have numpy 2.1.0 which is incompatible.
# scipy 1.12.0 requires numpy<1.29.0,>=1.22.4, but you have numpy 2.1.0 which is incompatible.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 2.1.0 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed galileo-core-2.11.1 importlib-metadata-8.4.0 numpy-2.1.0 promptquality-0.58.1 pydantic-settings-2.4.0 pyjwt-2.9.0 python-dotenv-1.0.1
# Collecting chromadb
#   Downloading chromadb-0.5.5-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pydantic>=1.9 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (2.8.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.112.2-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting numpy<2.0.0,>=1.22.5 (from chromadb)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.6.3-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.19.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (1.26.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (4.66.3)
# Requirement already satisfied: overrides>=7.3.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (6.4.3)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (1.65.5)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: orjson>=3.9.12 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: packaging>=19.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.38.4-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /opt/conda/envs/summarization/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /opt/conda/envs/summarization/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.2)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /opt/conda/envs/summarization/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /opt/conda/envs/summarization/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.4)
# Requirement already satisfied: sympy in /opt/conda/envs/summarization/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Collecting importlib-metadata<=8.0.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-8.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl.metadata (2.5 kB)
# ...
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Downloading chromadb-0.5.5-py3-none-any.whl (584 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 576.3 kB/s eta 0:00:00a 0:00:01
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 153.1 kB/s eta 0:00:0000:0100:03
# Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
# Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Downloading fastapi-0.112.2-py3-none-any.whl (93 kB)
# Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 199.2 kB/s eta 0:00:00a 0:00:01
# Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 324.9 kB/s eta 0:00:0000:0100:03
# Downloading onnxruntime-1.19.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 353.5 kB/s eta 0:00:0000:0100:02
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
# Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
# Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
# Downloading posthog-3.6.3-py2.py3-none-any.whl (53 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading rich-13.8.0-py3-none-any.whl (241 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.38.4-py3-none-any.whl (71 kB)
# Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 396.7 kB/s eta 0:00:0000:0100:01
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
# Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=d1a4db90a9003e5392e99519cd334393d7cef66ba7dfe7845d132b4c9ce0d94b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, uvicorn, shellingham, pyproject_hooks, opentelemetry-util-http, opentelemetry-proto, numpy, mdurl, humanfriendly, httptools, googleapis-common-protos, bcrypt, backoff, asgiref, watchfiles, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, markdown-it-py, coloredlogs, chroma-hnswlib, build, rich, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, typer, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.0
#     Uninstalling numpy-2.1.0:
#       Successfully uninstalled numpy-2.1.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.26.0
#     Uninstalling opentelemetry-api-1.26.0:
#       Successfully uninstalled opentelemetry-api-1.26.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.47b0
#     Uninstalling opentelemetry-semantic-conventions-0.47b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.47b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.26.0
#     Uninstalling opentelemetry-sdk-1.26.0:
#       Successfully uninstalled opentelemetry-sdk-1.26.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow-skinny 2.15.0 requires importlib-metadata!=4.7.0,<8,>=3.7.0, but you have importlib-metadata 8.4.0 which is incompatible.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.4 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 build-1.2.1 chroma-hnswlib-0.7.6 chromadb-0.5.5 coloredlogs-15.0.1 fastapi-0.112.2 googleapis-common-protos-1.65.0 httptools-0.6.1 humanfriendly-10.0 kubernetes-30.1.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-4.1.0 monotonic-1.6 numpy-1.26.4 onnxruntime-1.19.0 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 posthog-3.6.3 pypika-0.48.9 pyproject_hooks-1.1.0 rich-13.8.0 shellingham-1.5.4 starlette-0.38.4 typer-0.12.5 uvicorn-0.30.6 uvloop-0.20.0 watchfiles-0.24.0 websockets-13.0.1
# Requirement already satisfied: sentence-transformers in /opt/conda/envs/summarization/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers) (4.66.3)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers) (2.2.1+cu118)
# Requirement already satisfied: numpy in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers) (1.5.0)
# Requirement already satisfied: scipy in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers) (1.12.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers) (0.24.6)
# Requirement already satisfied: Pillow in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==8.7.0.84 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (8.7.0.84)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.19.3 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.8.86)
# Requirement already satisfied: triton==2.2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: openai in /opt/conda/envs/summarization/lib/python3.10/site-packages (1.43.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai) (4.66.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/envs/summarization/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Collecting webvtt-py
#   Downloading webvtt_py-0.5.1-py3-none-any.whl.metadata (3.4 kB)
# Downloading webvtt_py-0.5.1-py3-none-any.whl (19 kB)
# Installing collected packages: webvtt-py
# Successfully installed webvtt-py-0.5.1

# %% [markdown]
# Also, we are manually configuring Hugging Face cache, so that all downloaded models are persisted in the local folder, so they can be reused even after the workspace is restarted. This also should be provided by a future feature of AI Studio

# %%
import os
os.environ["HF_HOME"] = "/home/jovyan/local/hugging_face"
os.environ["HF_HUB_CACHE"] = "/home/jovyan/local/hugging_face/hub"

# %% [markdown]
# ## Step 1: Loading the data from the transcript
#
# At first, we need to read the data from the transcript. As our transcript is in the .vtt format, we use a library called webvtt-py to read the content. As the text is a trancript of audio/video, it is organized in small chunks of conversation, each containing a sequential id, the time of the start and end of the chunk, and the text content (often in the form speaker:content).
#
# From this data, we expect to extract the actual content,  while keeping reference to the other metadata - for this reason, we are loading all the data into a Pandas dataset.

# %%
import webvtt
import pandas as pd

data = {
    "id": [],
    "speaker": [],
    "content": [],
    "start": [],
    "end": []
}

for caption in webvtt.read('data/sample_transcript.vtt'):
    line = caption.text.split(":")
    while len(line) < 2:
        line = [''] + line
    data["id"].append(caption.identifier)
    data["speaker"].append(line[0].strip())
    data["content"].append(line[1].strip())
    data["start"].append(caption.start)
    data["end"].append(caption.end)
    
df = pd.DataFrame(data)

# %% [markdown]
# ## Step 2: Semantic chunking of the transcript
# At first, we need to read the data from the transcript. As our transcript is in the .vtt format, we use a library called webvtt-py to read the content. As the text is a trancript of audio/video, it is organized in small chunks of conversation, each containing a sequential id, the time of the start and end of the chunk, and the text content (often in the form speaker:content).
#
# From this data, we expect to extract the actual content,  while keeping reference to the other metadata - for this reason, we are loading all the data into a Pandas dataset.

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cosine

embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
embeddings = embedding_model.encode(df.content)
# Out:
# /opt/conda/envs/summarization/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# 2024-09-05 23:44:56.007509: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-05 23:44:58.093847: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /opt/conda/envs/summarization/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
class SemanticSplitter():
    def __init__ (self, content, embedding_model, partition_count = 10, quantile = 0.9):
        self.content = content
        self.embedding_model = embedding_model
        self.partition_count = partition_count
        self.quantile = quantile
        self.embeddings = embedding_model.encode(content)
        self.distances = [cosine(embeddings[i - 1], embeddings[i]) for i in range(1, len(embeddings))]
        self.breaks = []
        self.centroids = []
        self.load_breaks()

    def centroid_distance(self, embedding_id, centroid_id):
        return cosine(self.embeddings[embedding], self.centroid[centroid])

    def adjust_neighbors(self):
        self.breaks = []

    def load_breaks(self, method = 'number'):
        if method == 'number':
            self.breaks = np.sort(np.argpartition(self.distances, self.partition_count)[0:self.partition_count])
        elif method == 'quantiles':
            threshold = np.quantile(self.distances, self.quantile)
            self.breaks = [i for i, v in enumerate(self.distances) if v >= threshold]
        else:
            self.breaks = []

    def get_centroid(self, beginning, end):
        return embedding_model.encode('\n'.join(self.content[beginning : end]))
    
    def load_centroids(self):
        if len(self.breaks) == 0:
            self.centroids = [self.get_centroid(0, len(self.content))]
        else:
            self.centroids = []
            beginning = 0
            for break_position in self.breaks:
                self.centroids += [self.get_centroid(beginning, break_position + 1)]
                beginning = break_position + 1
            self.centroids += [self.get_centroid(beginning, len(self.content))]

    def get_chunk(self, beginning, end):
        return '\n'.join(self.content[beginning : end])
    
    def get_chunks(self):
        if len(self.breaks) == 0:
            return [self.get_chunk(0, len(self.content))]
        else:
            chunks = []
            beginning = 0
            for break_position in self.breaks:
                chunks += [self.get_chunk(beginning, break_position + 1)]
                beginning = break_position + 1
            chunks += [self.get_chunk(beginning, len(self.content))]
        return chunks

# %%
splitter = SemanticSplitter(df.content, embedding_model)

# %%
chunks = splitter.get_chunks()

# %% [markdown]
# ## Step 2: Using a LLM model to Summarize each chunk
# In our example, we are going to summarize each individual chunk separately. This solution might be advantageous in different situations:
#  * When the original text is too big , or the loaded model works with a context that is too small. In this scenario, breaking information into chunks are necessary to allow the model to be applied
#  * When the user wants to make sure that all the separate topics of a conversation are covered into the summarized version. An extra step could be added to allow some verification or manual configuration of the chunks to allow the user to customize the output
#
# To achieve this goal, we load a LLM model (that can be a cloud or a local model) and use a summarization prompt

# %%
prompt_template = '''
The following text is an excerpt of the transcription of a presentation:

### 
{context} 
###

Please, produce a single paragraph summarizing the given excerpt.
'''

# %%
import os
from langchain_openai import OpenAI

os.environ["OPENAI_API_KEY"] = "INSERT KEY"
llm = OpenAI(model_name="gpt-3.5-turbo-instruct")

# %%
### Alternate code to connect to Hugging Face models

#import yaml
#with open('config.yaml') as file:
    #config = yaml.safe_load(file)
#huggingfacehub_api_token = config["hf_key"]
#repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
#llm = HuggingFaceEndpoint(
   #huggingfacehub_api_token=huggingfacehub_api_token,
   #repo_id=repo_id,
#)

# %%
### Alternate code to load local models

#from langchain_core.callbacks import CallbackManager, StreamingStdOutCallbackHandler
#from langchain_community.llms import LlamaCpp

#callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])

#llm = LlamaCpp(
            #model_path="/home/jovyan/datafabric/Llama7b/ggml-model-f16-Q5_K_M.gguf",
            #n_gpu_layers=64,
            #n_batch=512,
            #n_ctx=4096,
            #max_tokens=1024,
            #f16_kv=True,  
            #callback_manager=callback_manager,
            #verbose=False,
            #stop=[],
            #streaming=False,
            #temperature=0.4,
        #)

# %% [markdown]
# ## Step 6: Connect to Galileo
# Through the Galileo library called Prompt Quality, we connect our API generated in the Galileo console to log in. To get your ApiKey, use this link: https://console.hp.galileocloud.io/api-keys

# %%
import promptquality as pq

os.environ['GALILEO_API_KEY'] = "pC_FeK6dQgygTQSMEzbHSYdsa1A_nG4QeqdjkMewamw" #your api Key
galileo_url = "https://console.hp.galileocloud.io/"
pq.login(galileo_url)
# Out:
# 👋 You have logged into 🔭 Galileo (https://console.hp.galileocloud.io/) as rafael.borges@hp.com.
# Config(console_url=Url('https://console.hp.galileocloud.io/'), username=None, password=None, api_key=SecretStr('**********'), token=SecretStr('**********'), current_user='rafael.borges@hp.com', current_project_id=None, current_project_name=None, current_run_id=None, current_run_name=None, current_run_url=None, current_run_task_type=None, current_template_id=None, current_template_name=None, current_template_version_id=None, current_template_version=None, current_template=None, current_dataset_id=None, current_job_id=None, current_prompt_optimization_job_id=None, api_url=Url('https://api.hp.galileocloud.io/'))

# %%
pq.run(project_name="simple-prompt-with-chatgpt",
       template=my_prompt_template,
       settings=pq.Settings(model_alias='ChatGPT (16K context)',
                            temperature=0.1,
                            max_tokens=400))

# %% [markdown]
# Through callbacks, we choose the metrics we want to monitor via the Galileo console. We pass a list of queries to run our created chain and log in to Galileo.

# %%
dir(pq.Scorers)
# Out:
# ['__class__',
#  '__doc__',
#  '__members__',
#  '__module__',
#  'chunk_attribution_utilization_luna',
#  'chunk_attribution_utilization_plus',
#  'completeness_luna',
#  'completeness_plus',
#  'context_adherence_luna',
#  'context_adherence_plus',
#  'context_relevance',
#  'correctness',
#  'pii',
#  'prompt_injection',
#  'prompt_perplexity',
#  'sexist',
#  'tone',
#  'toxicity']
